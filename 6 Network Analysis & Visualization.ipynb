# %%
import os
import re
import datetime as dt
import time
import random
# import sqlite3
import json

# data science
import math
import numpy as np
import pandas as pd

# %%
# configurations

# Allow multiple outputs for each cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')

# display all columns
pd.set_option('display.max_columns', None)

# suppress auto-conversion to scientific notation
pd.set_option('display.precision', 6)

# %% [markdown]
# ## network
# - design
#  - edge = from, srce, weight = sentiment
#  - edge weight = sentiment of tweet
#  - node size = # of retweets or mentions? # of followers?
#  - node color = gender?
#  - node content = user info, maybe URL
#  - tweet text - in edge or node?
#  - url to profile or tweet - in edge or node?

# %% [markdown]
# # Engagements & Interactions

# %%
associations = pd.read_csv('Data/associations.csv')
tweets = pd.read_csv('Data/tweets3.csv')

# %%
associations['associationType'].value_counts()
# focus: 'retweet'
# Out:
# retweet    224702
# self        93305
# reply       47014
# mention     33123
# Name: associationType, dtype: int64

# %%
retweets = associations[associations['associationType'] == 'retweet']
retweets
# Out:
#         associationId  tweetId       screenName associationType  \
# 5118             5119     4998         wordsrox         retweet
# 5119             5120     4999    Objective_ish         retweet
# 5121             5122     5001       criynwa293         retweet
# 5122             5123     5002       krissymom2         retweet
# 5124             5125     5004        jestor810         retweet
# 5125             5126     5005         LisaD787         retweet
# 5127             5128     5007           GBan14         retweet
# 5128             5129     5008  MsHasNoPatience         retweet
# 5130             5131     5010       Perspectvz         retweet
# 5131             5132     5011  CarnivoraUrsida         retweet
# 5133             5134     5013          dktturn         retweet
# 5135             5136     5015         emmala91         retweet
# 5136             5137     5016  lnreadingaround         retweet
# 5138             5139     5018    CadenceDenton         retweet
# 5142             5143     5021        Lehigh389         retweet
# 5143             5144     5022      CDNArchives         retweet
# 5146             5147     5025  TheRightImageLV         retweet
# 5149             5150     5028         cmcc1975         retweet
# 5152             5153     5031      itchywitch2         retweet
# 5153             5154     5032      susendipity         retweet
# 5154             5155     5033     RuralLiberal         retweet
# 5155             5156     5034          echerio         retweet
# 5159             5160     5038  MalindaMichell1         retweet
# 5162             5163     5041          dw_hanz         retweet
# 5163             5164     5042  vargas_ypvargas         retweet
# 5165             5166     5044       ShazzLa_La         retweet
# 5167             5168     5046          KitCoco         retweet
# 5168             5169     5047     SianLouise34         retweet
# 5170             5171     5049       lewisroche         retweet
# 5174             5175     5053        NimrLaura         retweet
# ...               ...      ...              ...             ...
# 398100         398101   393092         TIFF_NET         retweet
# 398101         398102   393093    Maureen_Lapis         retweet
# 398104         398105   393096       DeleHaynes         retweet
# 398105         398106   393097          mdowney         retweet
# 398106         398107   393098  CindyBo83683099         retweet
# 398108         398109   393100         apq11235         retweet
# 398109         398110   393101       Aschettino         retweet
# 398110         398111   393102   MonicaTaveras3         retweet
# 398112         398113   393104   SEBASTIANCAT75         retweet
# 398113         398114   393105      mminthecity         retweet
# 398114         398115   393106   writerincanada         retweet
# 398115         398116   393107    ellimayradrep         retweet
# 398116         398117   393108  viniciusnikolod         retweet
# 398118         398119   393110         nscrowba         retweet
# 398122         398123   393114      DebraRobbin         retweet
# 398123         398124   393115      StevenGuggs         retweet
# 398125         398126   393117  Tucs0nMortgages         retweet
# 398126         398127   393118  tlacovaspravask         retweet
# 398127         398128   393119      King17Larry         retweet
# 398128         398129   393120         Rparisee         retweet
# 398130         398131   393122   mikefreemanNFL         retweet
# 398131         398132   393123        tomcat159         retweet
# 398132         398133   393124     Zwoodbutcher         retweet
# 398134         398135   393126   AlgerianPalest         retweet
# 398135         398136   393127    kingofponders         retweet
# 398136         398137   393128      KosPatricia         retweet
# 398137         398138   393129     TwittaChicca         retweet
# 398138         398139   393130   BuffyLibSlayer         retweet
# 398139         398140   393131       boaomega22         retweet
# 398142         398143   393134           ZBezzt         retweet
#
#                 keyword
# 5118        NancyPelosi
# 5119        NancyPelosi
# 5121            jonfavs
# 5122        NancyPelosi
# 5124        NancyPelosi
# 5125          earthma23
# 5127        NancyPelosi
# 5128         SarahSpain
# 5130        NancyPelosi
# 5131      wesley_jordan
# 5133        NancyPelosi
# 5135           Newsweek
# 5136     BoringMe2Death
# 5138        LyndiLamont
# 5142    JenAshleyWright
# 5143       Marcodeplume
# 5146         JamesJordy
# 5149        MaureenShaw
# 5152        NancyPelosi
# 5153        NancyPelosi
# 5154         IjeomaOluo
# 5155        NancyPelosi
# 5159        NancyPelosi
# 5162        NancyPelosi
# 5163        NancyPelosi
# 5165         IjeomaOluo
# 5167        NancyPelosi
# 5168       ThrupennyBit
# 5170        NancyPelosi
# 5174        NancyPelosi
# ...                 ...
# 398100         TIFF_NET
# 398101     EdgeofSports
# 398104    OneMillionVjj
# 398105        Microsoft
# 398106         pewdrdad
# 398108  Suffragentleman
# 398109       nhregister
# 398110      LauraLoomer
# 398112    ProudResister
# 398113         MzCSmith
# 398114        _JustGee_
# 398115         pewdrdad
# 398116      LauraLoomer
# 398118      SteveBannen
# 398122  WithoutViolence
# 398123        Microsoft
# 398125             raju
# 398126      SteveBannen
# 398127      LauraLoomer
# 398128   peaceandjoy101
# 398130         MzCSmith
# 398131      SteveBannen
# 398132      NevadaJack2
# 398134   YousefMunayyer
# 398135  Suffragentleman
# 398136      SteveBannen
# 398137    TianaTheFirst
# 398138      LauraLoomer
# 398139  Suffragentleman
# 398142    OneMillionVjj
#
# [224702 rows x 5 columns]

# %%
retweets = retweets[retweets['screenName'] != retweets['keyword']]
retweets
# Out:
#         associationId  tweetId       screenName associationType  \
# 5118             5119     4998         wordsrox         retweet
# 5119             5120     4999    Objective_ish         retweet
# 5121             5122     5001       criynwa293         retweet
# 5122             5123     5002       krissymom2         retweet
# 5124             5125     5004        jestor810         retweet
# 5125             5126     5005         LisaD787         retweet
# 5127             5128     5007           GBan14         retweet
# 5128             5129     5008  MsHasNoPatience         retweet
# 5130             5131     5010       Perspectvz         retweet
# 5131             5132     5011  CarnivoraUrsida         retweet
# 5133             5134     5013          dktturn         retweet
# 5135             5136     5015         emmala91         retweet
# 5136             5137     5016  lnreadingaround         retweet
# 5138             5139     5018    CadenceDenton         retweet
# 5142             5143     5021        Lehigh389         retweet
# 5143             5144     5022      CDNArchives         retweet
# 5146             5147     5025  TheRightImageLV         retweet
# 5149             5150     5028         cmcc1975         retweet
# 5152             5153     5031      itchywitch2         retweet
# 5153             5154     5032      susendipity         retweet
# 5154             5155     5033     RuralLiberal         retweet
# 5155             5156     5034          echerio         retweet
# 5159             5160     5038  MalindaMichell1         retweet
# 5162             5163     5041          dw_hanz         retweet
# 5163             5164     5042  vargas_ypvargas         retweet
# 5165             5166     5044       ShazzLa_La         retweet
# 5167             5168     5046          KitCoco         retweet
# 5168             5169     5047     SianLouise34         retweet
# 5170             5171     5049       lewisroche         retweet
# 5174             5175     5053        NimrLaura         retweet
# ...               ...      ...              ...             ...
# 398099         398100   393091    SagarYogendra         retweet
# 398101         398102   393093    Maureen_Lapis         retweet
# 398104         398105   393096       DeleHaynes         retweet
# 398105         398106   393097          mdowney         retweet
# 398106         398107   393098  CindyBo83683099         retweet
# 398108         398109   393100         apq11235         retweet
# 398109         398110   393101       Aschettino         retweet
# 398110         398111   393102   MonicaTaveras3         retweet
# 398112         398113   393104   SEBASTIANCAT75         retweet
# 398113         398114   393105      mminthecity         retweet
# 398114         398115   393106   writerincanada         retweet
# 398115         398116   393107    ellimayradrep         retweet
# 398116         398117   393108  viniciusnikolod         retweet
# 398118         398119   393110         nscrowba         retweet
# 398122         398123   393114      DebraRobbin         retweet
# 398123         398124   393115      StevenGuggs         retweet
# 398125         398126   393117  Tucs0nMortgages         retweet
# 398126         398127   393118  tlacovaspravask         retweet
# 398127         398128   393119      King17Larry         retweet
# 398128         398129   393120         Rparisee         retweet
# 398130         398131   393122   mikefreemanNFL         retweet
# 398131         398132   393123        tomcat159         retweet
# 398132         398133   393124     Zwoodbutcher         retweet
# 398134         398135   393126   AlgerianPalest         retweet
# 398135         398136   393127    kingofponders         retweet
# 398136         398137   393128      KosPatricia         retweet
# 398137         398138   393129     TwittaChicca         retweet
# 398138         398139   393130   BuffyLibSlayer         retweet
# 398139         398140   393131       boaomega22         retweet
# 398142         398143   393134           ZBezzt         retweet
#
#                 keyword
# 5118        NancyPelosi
# 5119        NancyPelosi
# 5121            jonfavs
# 5122        NancyPelosi
# 5124        NancyPelosi
# 5125          earthma23
# 5127        NancyPelosi
# 5128         SarahSpain
# 5130        NancyPelosi
# 5131      wesley_jordan
# 5133        NancyPelosi
# 5135           Newsweek
# 5136     BoringMe2Death
# 5138        LyndiLamont
# 5142    JenAshleyWright
# 5143       Marcodeplume
# 5146         JamesJordy
# 5149        MaureenShaw
# 5152        NancyPelosi
# 5153        NancyPelosi
# 5154         IjeomaOluo
# 5155        NancyPelosi
# 5159        NancyPelosi
# 5162        NancyPelosi
# 5163        NancyPelosi
# 5165         IjeomaOluo
# 5167        NancyPelosi
# 5168       ThrupennyBit
# 5170        NancyPelosi
# 5174        NancyPelosi
# ...                 ...
# 398099      LauraLoomer
# 398101     EdgeofSports
# 398104    OneMillionVjj
# 398105        Microsoft
# 398106         pewdrdad
# 398108  Suffragentleman
# 398109       nhregister
# 398110      LauraLoomer
# 398112    ProudResister
# 398113         MzCSmith
# 398114        _JustGee_
# 398115         pewdrdad
# 398116      LauraLoomer
# 398118      SteveBannen
# 398122  WithoutViolence
# 398123        Microsoft
# 398125             raju
# 398126      SteveBannen
# 398127      LauraLoomer
# 398128   peaceandjoy101
# 398130         MzCSmith
# 398131      SteveBannen
# 398132      NevadaJack2
# 398134   YousefMunayyer
# 398135  Suffragentleman
# 398136      SteveBannen
# 398137    TianaTheFirst
# 398138      LauraLoomer
# 398139  Suffragentleman
# 398142    OneMillionVjj
#
# [222763 rows x 5 columns]

# %%
from pyvis.network import Network
def renderNetwork(df):
    net = Network(width='800px', height='600px', bgcolor='#222222', font_color='#EEEEEE', notebook=True)
    net.barnes_hut(overlap=1)
    
    nodes = pd.concat([df['screenName'], df['keyword']], 0)
    nodes = pd.DataFrame(nodes, columns=['screenName'])
    nodes.drop_duplicates(inplace=True)
    nodes.reset_index(drop=True, inplace=True)
    
    net.add_nodes(nodes['screenName'].tolist())
    net.add_edges(list(zip(df['screenName'], df['keyword'])))
    
    net.prep_notebook()
    return net.show(f"output/network_{time.strftime('%H%M')}.html")

def analyzeNetwork(net, df):
    nodes = pd.concat([df['screenName'], df['keyword']], 0)
    nodes = pd.DataFrame(nodes, columns=['screenName'])
    nodes.drop_duplicates(inplace=True)
    nodes.reset_index(drop=True, inplace=True)
    
    net.add_nodes(nodes['screenName'].tolist())
    net.add_edges(list(zip(df['screenName'], df['keyword'])))
    return net

# %%
def constructNetwork(retweets, currentNodes, leaves, branches, degrees, currentDegree):
    print(f'retweets:{len(retweets)}')
    print(f'current degree:{currentDegree}')
    print(f'current nodes:{currentNodes}')
    nextNodes = []
    edges = pd.DataFrame()
    for node in currentNodes:
        # unique users that retweeted initialNodes
        shortList = retweets[retweets['keyword'] == node]['screenName'].unique()

        # selected top n users from shortList that received the most retweets
        currentLeaves = retweets[retweets['keyword'].isin(shortList)]['keyword'].value_counts()[:leaves].index.tolist()

        # append branches to next nodes
        nextNodes = nextNodes + retweets[retweets['keyword'].isin(shortList)]['keyword'].value_counts()[:branches].index.tolist()

        # copy n edges from retweets stemming from current node
        newEdges = retweets[retweets['screenName'].isin(currentLeaves)&(retweets['keyword'] == node)][:leaves]

        if len(edges) == 0:
            edges = newEdges.copy()
        else:
            edges = pd.concat([edges,newEdges])

    edges['degree'] = currentDegree
    if degrees > 0:
        return pd.concat([edges,
                          constructNetwork(retweets[retweets['keyword'].isin(currentNodes) == False], 
                                           nextNodes,
                                           leaves,
                                           branches + 2, 
                                           degrees - 1,
                                           currentDegree + 1
                                          )],0)
    else:
        return edges

# %%
# initial nodes: 'TaranaBurke', 'Alyssa_Milano', 'LaurenJauregui', 'SenGillibrand'
currentNodes = ['TaranaBurke', 'Alyssa_Milano', 'LaurenJauregui', 'SenGillibrand']

leaves = 30
branches = 4
degrees = 5
currentDegree = 0

# %%
df = constructNetwork(df, currentNodes, leaves, branches, degrees, currentDegree)
df
# Out:
# retweets:222763
# current degree:0
# current nodes:['TaranaBurke', 'Alyssa_Milano', 'LaurenJauregui', 'SenGillibrand']
# retweets:199002
# current degree:1
# current nodes:['Blackamazon', 'womensmarch', 'AngryBlackLady', 'ShaunKing', 'Blackamazon', 'LadyThriller69', 'MaureenShaw', 'evry2min', 'infLAURENZA', 'DREWSINGS', 'DulleyTopBooks', 'PaganMediaBites', 'WomenOccupyHwd', 'chillibeanboy', 'ReignOfApril', 'SophiaBush']
# retweets:197094
# current degree:2
# current nodes:['ReaganGomez', 'shanikharris', 'IWriteAllDay_', 'terriah01', 'docfreeride', 'WebOften', 'VintageKnits', 'cdnwomenfdn', 'iSenseChange', 'htownfeminista', 'marygauthier_', 'Time4Rise', 'WentRogue', 'docfreeride', 'BrownGirlBegins', 'joylladiebnx', 'MadDiva007', 'FoxyJazzabelle', 'Ez4u2say_Janis', 'KelciRee', 'TinaBit', 'dairyblondeLN66', '_Aesthetixx', 'ReaganGomez', 'shanikharris', 'IWriteAllDay_', 'terriah01', 'docfreeride', 'WebOften', 'AynRandPaulRyan', 'kharyp', '_ShaunDougherty', 'gettinnoticedmo', 'Genosworld', 'BKnight1995', 'Shoq', 'kristenhinkson', 'NotInMyMarines', 'kaylaspag', 'femifesto', 'TheBADASS_army', 'hinterlandg', 'nakisnakis', 'PattyArquette', 'ivanamassetti', 'WomenFilmOfColr', 'RethinkingEve', 'TheRaDR', 'EllenBarkin', 'PrincessBravato', 'Elastigirl2018', 'SlythSeeker2017', 'lauraMcc1422', 'Nasty_Woman1', 'kellysue', 'DREWSINGS', 'MOVEprofPHD', 'creatrixtiara']
# retweets:194749
# current degree:3
# current nodes:['OutspokenE', 'SaraJaneMaki', 'whenpigsflyyy', 'politix_news', 'allthecdnpoli', 'KarenKrossing', 'blizzyou', 'burberryant', 'SaraJaneMaki', 'outlawjoZ', '_sirtainly', 'OutspokenE', 'SaraJaneMaki', 'ProudResister', 'omarvaid', 'debbiesideris', 'ArianeBellamar', 'Robyn_Resists', 'dawnresist', 'ProgressiveTex', 'arijameiers', 'lkjtexas', 'BlaisBlais5', 'realchrisdantes', 'everyhumanknows', 'EmilyRB', 'talk_mj', 'waltb31', 'oceanshaman', 'tampagirl19655', 'karenricks', 'austin_c_rick', 'Whitdiane47', 'YamileJana', 'judeaa', 'KgKathryn', 'AmbraBattilana', 'gabbyeubank', 'LMovieLowdown', 'IMFromMarsFilms', 'IndieJenFischer', 'unbreakablepenn', 'ERAUSANOW', 'Jeannie_Hartley', 'gabbyeubank', 'RavMABAY', 'rawlingseliza', 'saralynne65', 'scorpio292u', 'sar_oso', 'HillaryHutton', 'retsofdk', 'HarryPotterMAGE', 'GaladrielResist', 'THESTRA50825107', 'LesleyPro_04', 'monaeltahawy', 'Me_Too_Us', 'carinakolodny', 'dorothyk98']
# retweets:192473
# current degree:4
# current nodes:['Andywoodward44', 'BeTheChange800', 'swanmoonbaby', 'Andywoodward44', 'Andywoodward44', 'debbiesideris', 'CaptainsLog2017', 'laureldavilacpa', 'deejay90192', 'waltb31', 'Bella_ofA', 'Only4RM', 'CJPatruno', 'windmillcharger', 'randyprine', 'joncoopertweets', 'bjorkianrice', 'kansasfemale', 'KellieResists', 'ManMet80', 'KiwiShame', 'Boba_Cup', 'JacquelineHine1', 'costlylovewins', 'talk_mj', 'B52Malmet', 'laureldavilacpa', 'CJPatruno', 'WeNeededHillary', 'halesr2539', 'lsfarmer311', 'ccngg25', 'Astartiel', 'ToddHagopian', 'TomWellborn', 'scarletsletter', 'Wellness4You13', 'DrNat01', 'DMansini', 'Christi49131837', 'seterapia', 'PuestoLoco', 'summer7570', 'harmonyis1', 'GarrettRuby', 'PjjPjoje', 'erezshek', 'AndyQashou', 'docrocktex26', 'DMansini', 'ManMet80', 'CC4Future', 'ERAUSANOW', 'YoureWonder', 'gemma_brett', 'kcleland', 'ERAUSANOW', 'winterthur', 'StormResist', 'NurseChapel2017', 'najwazebian', 'TinaTinde', 'letat_lechat', 'MattMurph24', 'JaneCaro', 'NoFascistsPls', 'jambie61', 'EricaLWilliams7', 'DMAE2', 'ejwillingham', 'TinaTinde', 'protesting2016', 'RYBWomen', 'alaskawater']
# retweets:191222
# current degree:5
# current nodes:['odetteroulette', 'thewad25', 'Media_PPP', 'allisw0nderland', 'marymurfee', 'TaggartRehnn', '_dralaterdzo', 'lavenderblue27', 'lola_patty', 'whatllufallfor', 'CJPatruno', 'BlackNewbornDem', '6nsinvt', 'bannerite', 'KimbyIndy', 'BeverleeHughes3', 'SimpleWonders82', 'GayEqualGlobal', 'PolitiKiss1600', 'jambie61', 'kkhooray', 'bruntofitall', 'TaggartRehnn', 'MarionBurr5', 'MooseLambResist', 'meganmckenzie94', 'sharonvt75', 'TomWellborn', 'Justica4all', 'AllonsyCrazy', 'LisaHauser8', 'Thedude67111', 'Kschmidt67', 'CltrotLyn', 'MDemforce', 'Tlyncan', 'chippy3166', 'PhoenixTatsCuts', 'OHenryHernandez', 'SoulFlyTry', 'PrivateAbyss', 'lisamikol1969', 'KATHLEE23339303', 'Astartiel', 'SunflowerSoul71', 'SAdemocrat', 'carlettej1', 'horridpoplyrics', 'negasonic2017', 'SteveIParty', 'MooseLambResist', 'parkse', 'negasonic2017', 'whatthefox', 'CJPatruno', 'Maryc1850Sadler', 'FrecklesXX20', 'LadySif2017', 'CJPatruno', 'BlackNewbornDem', '6nsinvt', 'TaggartRehnn', 'MarionBurr5', 'ScaryHomeschool', 'debiowens', 'GGevirtz', 'PjjPjoje', 'jawja100', 'ShannonEG68', 'bannerite', 'djmincey11', 'BeverleeHughes3', 'CaraOriel', 'AudreyGarden', 'patrioticmomusa', 'LalaMusings', 'WgarNews', 'kitty4hawks', 'LisaTalmadge', 'Wellness4You13', 'DMAE2', 'RFreeba', 'parkse', 'Anootchka', 'Shy_Survivor', 'MeTooShortFilm', 'Passie_Kracht', 'bjportraits', 'feraldaughter', 'jackiecall3', 'Bfolly', 'BKmelo70', 'BernadetteMhill', 'Wellness4You13', 'CondieKristine', 'kkhooray', 'CharleyUtah', 'WesthaverEmily', 'RYBWomen', 'cfiig8200', 'KlassmannAngela', 'HeleenTouquet', 'vitalifranc', 'QueenMab87', 'theAWParty', 'DrLindaShelton', 'birdgirl1001', 'jambie61', 'TheCampaignFilm', 'MooPersists', 'Plantflowes', 'cinemaven', 'BeverleeHughes3', 'edgeoforever', 'GarrettRuby', 'ResistTilDeath', 'ABCthedrum', 'whereisdaz', 'JConabicycle', 'pahstock', 'PjjPjoje', 'seterapia', 'RYBWomen', 'cfiig8200', 'KlassmannAngela', 'HeleenTouquet', 'vitalifranc', 'YoureWonder']
#         associationId  tweetId       screenName associationType  \
# 96455           96456    95009      CeciliaNano         retweet
# 100882         100883    99369   AngryBlackLady         retweet
# 111701         111702   110008     BettyBuckley         retweet
# 137204         137205   135259    IWriteAllDay_         retweet
# 137813         137814   135863        IBJIYONGI         retweet
# 138652         138653   136696        JeanHyams         retweet
# 142687         142688   140661     shanikharris         retweet
# 143281         143282   141246      Blackamazon         retweet
# 144995         144996   142930    Compassioning         retweet
# 145287         145288   143221        leanne4pa         retweet
# 145661         145662   143596  windmillcharger         retweet
# 146325         146326   144250       sharmili_m         retweet
# 146552         146553   144476           shreec         retweet
# 146972         146973   144895         nwseal11         retweet
# 147346         147347   145265    JW4Resistance         retweet
# 147399         147400   145318           kharyp         retweet
# 147417         147418   145336        ShaunKing         retweet
# 155719         155720   153584  BreaktheCycleDV         retweet
# 156371         156372   154229       sharmili_m         retweet
# 158854         158855   156677           GGENYC         retweet
# 158910         158911   156733           GGENYC         retweet
# 159067         159068   156879       QueenMab87         retweet
# 160272         160273   158080  domesticworkers         retweet
# 160351         160352   158159         aijenpoo         retweet
# 160613         160614   158418      farrah_khan         retweet
# 160712         160713   158519      YWCA_Canada         retweet
# 160732         160733   158539       knowyourIX         retweet
# 160771         160772   158578   EqualRightsAdv         retweet
# 160795         160796   158602  domesticworkers         retweet
# 163007         163008   160775       EmmaBunnie         retweet
# ...               ...      ...              ...             ...
# 348953         348954   344501       lynlinking         retweet
# 372556         372557   367752       newmatilda         retweet
# 372559         372560   367755       newmatilda         retweet
# 369986         369987   365200     mrsmichaud13         retweet
# 380366         380367   375427           sdterp         retweet
# 346290         346291   341856   AlasscanIsBack         retweet
# 175501         175502   173110    RoxanneSukhan         retweet
# 78552           78553    77335  patrioticmomusa         retweet
# 64541           64542    63495     ERAMinnesota         retweet
# 287054         287055   283262    Kvindesamfund         retweet
# 70119           70120    69007       theAWParty         retweet
# 117053         117054   115296       missydiggs         retweet
# 375081         375082   370224     VuhJJDentata         retweet
# 71660           71661    70526       QueenMab87         retweet
# 75166           75167    73989       djmincey11         retweet
# 141525         141526   139527        ICarrollJ         retweet
# 153076         153077   150956    SallyAlbright         retweet
# 368726         368727   363956        melodijoy         retweet
# 141480         141481   139486      MooPersists         retweet
# 158948         158949   156770       armsivilli         retweet
# 326276         326277   322052       whereisdaz         retweet
# 343241         343242   338823       SallyRMelb         retweet
# 350148         350149   345675       whereisdaz         retweet
# 362666         362667   358025  AllThingsAfrica         retweet
# 368572         368573   363808  SpotlightForYou         retweet
# 371109         371110   366311       raywilton4         retweet
# 374785         374786   369932  NotUnderBondage         retweet
# 84880           84881    83586    KittyAndPitty         retweet
# 98981           98982    97494   SmallFarmDairy         retweet
# 287054         287055   283262    Kvindesamfund         retweet
#
#                keyword  degree
# 96455      TaranaBurke       0
# 100882     TaranaBurke       0
# 111701     TaranaBurke       0
# 137204     TaranaBurke       0
# 137813     TaranaBurke       0
# 138652     TaranaBurke       0
# 142687     TaranaBurke       0
# 143281     TaranaBurke       0
# 144995     TaranaBurke       0
# 145287     TaranaBurke       0
# 145661     TaranaBurke       0
# 146325     TaranaBurke       0
# 146552     TaranaBurke       0
# 146972     TaranaBurke       0
# 147346     TaranaBurke       0
# 147399     TaranaBurke       0
# 147417     TaranaBurke       0
# 155719     TaranaBurke       0
# 156371     TaranaBurke       0
# 158854     TaranaBurke       0
# 158910     TaranaBurke       0
# 159067     TaranaBurke       0
# 160272     TaranaBurke       0
# 160351     TaranaBurke       0
# 160613     TaranaBurke       0
# 160712     TaranaBurke       0
# 160732     TaranaBurke       0
# 160771     TaranaBurke       0
# 160795     TaranaBurke       0
# 163007     TaranaBurke       0
# ...                ...     ...
# 348953        WgarNews       5
# 372556        WgarNews       5
# 372559        WgarNews       5
# 369986     kitty4hawks       5
# 380366    LisaTalmadge       5
# 346290         RFreeba       5
# 175501    Shy_Survivor       5
# 78552      jackiecall3       5
# 64541           Bfolly       5
# 287054       cfiig8200       5
# 70119       QueenMab87       5
# 117053      QueenMab87       5
# 375081      QueenMab87       5
# 71660       theAWParty       5
# 75166       theAWParty       5
# 141525      theAWParty       5
# 153076      theAWParty       5
# 368726  DrLindaShelton       5
# 141480    birdgirl1001       5
# 158948     Plantflowes       5
# 326276      ABCthedrum       5
# 343241      ABCthedrum       5
# 350148      ABCthedrum       5
# 362666      ABCthedrum       5
# 368572      ABCthedrum       5
# 371109      ABCthedrum       5
# 374785      ABCthedrum       5
# 84880     JConabicycle       5
# 98981     JConabicycle       5
# 287054       cfiig8200       5
#
# [649 rows x 6 columns]

# %%
_ = df[(df['keyword'].isin(df['screenName']) == False) & (df['degree'] != 0)].index
df = retweets#.drop(_)

# %%
renderNetwork(df)
# Out:
#         <iframe
#             width="800px"
#             height="600px"
#             src="output/network_1702.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Network Analysis

# %%
net = Network(width='1280px', height='700px', bgcolor='#222222', font_color='#EEEEEE', notebook=True)
net.barnes_hut(overlap=1)
net = analyzeNetwork(net, df)

# %%
net.get_adj_list()
# Out:
# {'CeciliaNano': {'TaranaBurke'},
#  'AngryBlackLady': {'BrownGirlBegins',
#   'FoxyJazzabelle',
#   'MadDiva007',
#   'PrettyFootWoman',
#   'TaranaBurke',
#   'WentRogue',
#   'docfreeride',
#   'joylladiebnx',
#   'kyliesparks',
#   'lydiaelise'},
#  'BettyBuckley': {'TaranaBurke'},
#  'IWriteAllDay_': {'Blackamazon', 'TaranaBurke'},
#  'IBJIYONGI': {'TaranaBurke'},
#  'JeanHyams': {'TaranaBurke'},
#  'shanikharris': {'Blackamazon', 'SenGillibrand', 'TaranaBurke'},
#  'Blackamazon': {'IWriteAllDay_',
#   'Megan_Sass',
#   'ReaganGomez',
#   'StlGal_36',
#   'TaranaBurke',
#   'WebOften',
#   'dana_flo',
#   'docfreeride',
#   'everyhumanknows',
#   'exfkaty',
#   'normandiewilson',
#   'shanikharris',
#   'terriah01'},
#  'Compassioning': {'TaranaBurke'},
#  'leanne4pa': {'TaranaBurke'},
#  'windmillcharger': {'MooseLambResist', 'ProudResister', 'TaranaBurke'},
#  'shreec': {'TaranaBurke'},
#  'nwseal11': {'TaranaBurke'},
#  'JW4Resistance': {'TaranaBurke'},
#  'kharyp': {'BlaisBlais5', 'MaureenShaw', 'TaranaBurke', 'lkjtexas'},
#  'ShaunKing': {'Ez4u2say_Janis',
#   'KelciRee',
#   'TaranaBurke',
#   'TinaBit',
#   '_Aesthetixx',
#   'dairyblondeLN66'},
#  'BreaktheCycleDV': {'TaranaBurke'},
#  'GGENYC': {'TaranaBurke'},
#  'QueenMab87': {'TaranaBurke',
#   'VuhJJDentata',
#   'letat_lechat',
#   'missydiggs',
#   'theAWParty'},
#  'domesticworkers': {'TaranaBurke'},
#  'aijenpoo': {'TaranaBurke'},
#  'farrah_khan': {'TaranaBurke'},
#  'sreneelong': {'TaranaBurke'},
#  'YWCA_Canada': {'SenGillibrand', 'TaranaBurke'},
#  'knowyourIX': {'TaranaBurke'},
#  'EqualRightsAdv': {'TaranaBurke'},
#  'EmmaBunnie': {'Alyssa_Milano', 'TaranaBurke'},
#  'PattyArquette': {'KgKathryn', 'TaranaBurke', 'WomenOccupyHwd', 'judeaa'},
#  'paulpender1': {'Alyssa_Milano'},
#  'JSavoly': {'Alyssa_Milano'},
#  'amplifirenews_': {'Alyssa_Milano'},
#  'cindygallop': {'Alyssa_Milano', 'AynRandPaulRyan'},
#  'Mattison': {'Alyssa_Milano'},
#  'VintageKnits': {'Alyssa_Milano', 'SenGillibrand'},
#  'YourAnonRevolt': {'Alyssa_Milano'},
#  'mattnicholas': {'Alyssa_Milano'},
#  'Amoney666': {'Alyssa_Milano'},
#  'PaganMediaBites': {'Alyssa_Milano', 'LaurenJauregui', 'SenGillibrand'},
#  'evry2min': {'Alyssa_Milano',
#   'NotInMyMarines',
#   'Shoq',
#   'TheBADASS_army',
#   'femifesto',
#   'kaylaspag',
#   'kristenhinkson'},
#  'MaureenShaw': {'Alyssa_Milano',
#   'AuthorKimberley',
#   'AynRandPaulRyan',
#   'BKnight1995',
#   'BlaisBlais5',
#   'Genosworld',
#   'Perspectvz',
#   'RenaSofer',
#   'Trumpgot2go',
#   'VuhJJDentata',
#   '_ShaunDougherty',
#   'gettinnoticedmo',
#   'jenscorpio83',
#   'kharyp',
#   'marie_skou'},
#  'serenityatsea': {'Alyssa_Milano'},
#  'ArianeBellamar': {'Alyssa_Milano',
#   'AynRandPaulRyan',
#   'ToddHagopian',
#   'TomWellborn',
#   'Wellness4You13',
#   'scarletsletter'},
#  'Genosworld': {'Alyssa_Milano', 'EmilyRB', 'MaureenShaw'},
#  'wendydshaffer': {'Alyssa_Milano', 'AynRandPaulRyan', 'SenGillibrand'},
#  'rubybelson': {'Alyssa_Milano'},
#  'letat_lechat': {'Alyssa_Milano',
#   'BeverleeHughes3',
#   'DrLindaShelton',
#   'MooPersists',
#   'Plantflowes',
#   'QueenMab87',
#   'TheCampaignFilm',
#   'birdgirl1001',
#   'cinemaven',
#   'edgeoforever',
#   'jambie61',
#   'monaeltahawy',
#   'theAWParty'},
#  'RachelAzzara': {'Alyssa_Milano'},
#  'safeagain1': {'Alyssa_Milano'},
#  'VA174navyvet': {'Alyssa_Milano'},
#  'Carmen_TD8_': {'Alyssa_Milano', 'Tlyncan', 'carlettej1'},
#  'PjjPjoje': {'Alyssa_Milano',
#   'PuestoLoco',
#   'SenGillibrand',
#   'WgarNews',
#   'jambie61',
#   'kitty4hawks',
#   'realchrisdantes'},
#  'MichelleSauber': {'LaurenJauregui'},
#  'DREWSINGS': {'LaurenJauregui', 'ReignOfApril', 'hinterlandg', 'nakisnakis'},
#  'DulleyTopBooks': {'LaurenJauregui'},
#  'halevader': {'LaurenJauregui'},
#  'JustChar83': {'LaurenJauregui'},
#  'infLAURENZA': {'LaurenJauregui'},
#  'kristenhinkson': {'LaurenJauregui',
#   'austin_c_rick',
#   'evry2min',
#   'karenricks'},
#  'KelciRee': {'LaurenJauregui', 'ShaunKing'},
#  'JessesGirl588': {'LaurenJauregui'},
#  'nicolexhames': {'LaurenJauregui'},
#  'NoFascistsPls': {'JConabicycle',
#   'SenGillibrand',
#   'monaeltahawy',
#   'pahstock'},
#  'chillibeanboy': {'Elastigirl2018',
#   'Nasty_Woman1',
#   'PrincessBravato',
#   'SenGillibrand',
#   'SlythSeeker2017',
#   'lauraMcc1422'},
#  'unbreakablepenn': {'RethinkingEve', 'SenGillibrand', 'gemma_brett'},
#  'LisaTalmadge': {'SenGillibrand', 'docrocktex26', 'sdterp'},
#  'ashleyn1cole': {'SenGillibrand'},
#  'Ophelia22345': {'SenGillibrand'},
#  'IndivisNewRoc': {'SenGillibrand'},
#  'TexDem16': {'SenGillibrand'},
#  'JenSiebelNewsom': {'SenGillibrand'},
#  'SophiaBush': {'SenGillibrand'},
#  'AuthorKimberley': {'AynRandPaulRyan', 'MaureenShaw', 'SenGillibrand'},
#  'BKnight1995': {'MaureenShaw', 'SenGillibrand', 'talk_mj'},
#  'terriah01': {'Blackamazon', 'SenGillibrand'},
#  'BrianSwiftie13': {'SenGillibrand'},
#  'ReignOfApril': {'DREWSINGS',
#   'MOVEprofPHD',
#   'SenGillibrand',
#   'creatrixtiara',
#   'kellysue'},
#  'ivanamassetti': {'AmbraBattilana',
#   'IMFromMarsFilms',
#   'LMovieLowdown',
#   'SenGillibrand',
#   'WomenOccupyHwd',
#   'gabbyeubank'},
#  'TinaTinde': {'HeleenTouquet',
#   'KlassmannAngela',
#   'Me_Too_Us',
#   'RYBWomen',
#   'SenGillibrand',
#   'cfiig8200',
#   'monaeltahawy',
#   'vitalifranc'},
#  'WomenOccupyHwd': {'EllenBarkin',
#   'IMFromMarsFilms',
#   'JeniferAleja_S',
#   'LMovieLowdown',
#   'PattyArquette',
#   'RethinkingEve',
#   'RoArquette',
#   'SenGillibrand',
#   'Watchdogsniffer',
#   'WeavingHouse',
#   'WomenFilmOfColr',
#   'gabbyeubank',
#   'hipcinema',
#   'ivanamassetti',
#   'myeucatastrophe'},
#  'RobinBrenizer': {'SenGillibrand'},
#  'YMBBastepaway': {'SenGillibrand'},
#  'MadisonSiriusXM': {'SenGillibrand'},
#  'ShannonEG68': {'PuestoLoco', 'SenGillibrand', 'xscoutie'},
#  'donohue_rebekah': {'SenGillibrand'},
#  'normandiewilson': {'Blackamazon'},
#  'WebOften': {'Blackamazon'},
#  'docfreeride': {'AngryBlackLady', 'Blackamazon', 'SaraJaneMaki'},
#  'ReaganGomez': {'Blackamazon', 'OutspokenE'},
#  'dana_flo': {'Blackamazon'},
#  'StlGal_36': {'Blackamazon'},
#  'exfkaty': {'Blackamazon'},
#  'Megan_Sass': {'Blackamazon'},
#  'everyhumanknows': {'Blackamazon', 'gettinnoticedmo'},
#  'joylladiebnx': {'AngryBlackLady'},
#  'PrettyFootWoman': {'AngryBlackLady'},
#  'FoxyJazzabelle': {'AngryBlackLady'},
#  'BrownGirlBegins': {'AngryBlackLady'},
#  'MadDiva007': {'AngryBlackLady', 'outlawjoZ'},
#  'lydiaelise': {'AngryBlackLady'},
#  'WentRogue': {'AngryBlackLady'},
#  'kyliesparks': {'AngryBlackLady'},
#  'dairyblondeLN66': {'ShaunKing'},
#  'TinaBit': {'ShaunKing'},
#  'Ez4u2say_Janis': {'ShaunKing', '_sirtainly'},
#  '_Aesthetixx': {'ShaunKing'},
#  'RenaSofer': {'MaureenShaw'},
#  'Trumpgot2go': {'MaureenShaw'},
#  'AynRandPaulRyan': {'ArianeBellamar',
#   'Astorix23',
#   'AuthorKimberley',
#   'BernadetteMhill',
#   'KimbyIndy',
#   'MattMurph24',
#   'MaureenShaw',
#   'Merrirrro',
#   'Pajjr2016',
#   'ProgressiveTex',
#   'ProudResister',
#   'Robyn_Resists',
#   'RolndKarl',
#   'SimonClaydon',
#   'Thearst',
#   '_dralaterdzo',
#   'arijameiers',
#   'cajunsmiley',
#   'cindygallop',
#   'dawnresist',
#   'debbiesideris',
#   'dittycommittee',
#   'htownfeminista',
#   'jackiecall3',
#   'lkjtexas',
#   'mercury_road',
#   'nickiknowsnada',
#   'omarvaid',
#   'rcrockett',
#   'wendydshaffer'},
#  'BlaisBlais5': {'MaureenShaw', 'kharyp'},
#  'jenscorpio83': {'MaureenShaw', 'ProudResister', 'whatthefox'},
#  'Perspectvz': {'MaureenShaw'},
#  'gettinnoticedmo': {'MaureenShaw', 'everyhumanknows'},
#  'marie_skou': {'MaureenShaw'},
#  '_ShaunDougherty': {'MaureenShaw', 'realchrisdantes'},
#  'VuhJJDentata': {'MaureenShaw', 'QueenMab87'},
#  'Shoq': {'evry2min', 'oceanshaman', 'tampagirl19655', 'waltb31'},
#  'femifesto': {'evry2min'},
#  'TheBADASS_army': {'evry2min'},
#  'NotInMyMarines': {'Whitdiane47', 'YamileJana', 'evry2min'},
#  'kaylaspag': {'evry2min'},
#  'hinterlandg': {'DREWSINGS'},
#  'nakisnakis': {'DREWSINGS'},
#  'IMFromMarsFilms': {'WomenOccupyHwd', 'ivanamassetti'},
#  'RoArquette': {'WomenOccupyHwd'},
#  'myeucatastrophe': {'WomenOccupyHwd'},
#  'WeavingHouse': {'WomenOccupyHwd'},
#  'LMovieLowdown': {'WomenOccupyHwd', 'YoureWonder', 'ivanamassetti'},
#  'JeniferAleja_S': {'WomenOccupyHwd'},
#  'WomenFilmOfColr': {'IndieJenFischer', 'WomenOccupyHwd'},
#  'Watchdogsniffer': {'WomenOccupyHwd'},
#  'RethinkingEve': {'ERAUSANOW',
#   'Jeannie_Hartley',
#   'WomenOccupyHwd',
#   'gabbyeubank',
#   'unbreakablepenn'},
#  'gabbyeubank': {'ERAUSANOW',
#   'RethinkingEve',
#   'WomenOccupyHwd',
#   'ivanamassetti'},
#  'hipcinema': {'WomenOccupyHwd'},
#  'EllenBarkin': {'WomenOccupyHwd'},
#  'Elastigirl2018': {'GaladrielResist', 'HarryPotterMAGE', 'chillibeanboy'},
#  'SlythSeeker2017': {'LesleyPro_04', 'THESTRA50825107', 'chillibeanboy'},
#  'PrincessBravato': {'HillaryHutton',
#   'chillibeanboy',
#   'retsofdk',
#   'sar_oso',
#   'saralynne65',
#   'scorpio292u'},
#  'lauraMcc1422': {'chillibeanboy'},
#  'Nasty_Woman1': {'chillibeanboy'},
#  'kellysue': {'Me_Too_Us', 'ReignOfApril', 'carinakolodny', 'monaeltahawy'},
#  'MOVEprofPHD': {'ReignOfApril', 'dorothyk98'},
#  'creatrixtiara': {'ReignOfApril'},
#  'OutspokenE': {'ReaganGomez'},
#  'SaraJaneMaki': {'Andywoodward44', 'docfreeride'},
#  'outlawjoZ': {'MadDiva007'},
#  '_sirtainly': {'Ez4u2say_Janis'},
#  'KimbyIndy': {'AynRandPaulRyan', 'deejay90192'},
#  'dawnresist': {'AynRandPaulRyan', 'DMansini'},
#  'SimonClaydon': {'AynRandPaulRyan'},
#  'arijameiers': {'AynRandPaulRyan',
#   'GarrettRuby',
#   'PuestoLoco',
#   'harmonyis1',
#   'summer7570'},
#  'debbiesideris': {'Astartiel',
#   'AynRandPaulRyan',
#   'B52Malmet',
#   'CJPatruno',
#   'ProudResister',
#   'WeNeededHillary',
#   'ccngg25',
#   'halesr2539',
#   'laureldavilacpa',
#   'lsfarmer311'},
#  'Robyn_Resists': {'AynRandPaulRyan', 'DrNat01'},
#  'cajunsmiley': {'AynRandPaulRyan'},
#  'ProgressiveTex': {'AynRandPaulRyan', 'Christi49131837', 'seterapia'},
#  'Astorix23': {'AynRandPaulRyan'},
#  'ProudResister': {'2013Tran',
#   'AynRandPaulRyan',
#   'Bella_ofA',
#   'CJPatruno',
#   'CaptainsLog2017',
#   'Fisher_DanaR',
#   'HeyNikki1',
#   'KayZed14',
#   'Only4RM',
#   'PMueller2',
#   'StephenWunderl4',
#   'SullivanMonty',
#   'THESTRA50825107',
#   '_dralaterdzo',
#   'a_fly_guy',
#   'badgirl_loony',
#   'bmangh',
#   'costlylovewins',
#   'debbiesideris',
#   'deejay90192',
#   'idlechatter91',
#   'jenscorpio83',
#   'laureldavilacpa',
#   'ohwhatsina',
#   'parkse',
#   'paty1209f',
#   'randyprine',
#   'talk_mj',
#   'waltb31',
#   'windmillcharger'},
#  'omarvaid': {'AynRandPaulRyan',
#   'Boba_Cup',
#   'Can_ada',
#   'CherokeeNative3',
#   'GSB5719',
#   'HD4sanity_USAF',
#   'JacquelineHine1',
#   'KarenEd04044347',
#   'KellieResists',
#   'KiwiShame',
#   'LisaHauser8',
#   'ManMet80',
#   'Michellamio',
#   'MsTeacher80',
#   'Snarking_tRump',
#   'TheOnlyAlyMack',
#   'bjorkianrice',
#   'costlylovewins',
#   'joncoopertweets',
#   'kansasfemale',
#   'lacadri34',
#   'mamaduck9370',
#   'merryws95',
#   'personalitty',
#   'talk_mj'},
#  'nickiknowsnada': {'AynRandPaulRyan'},
#  'Pajjr2016': {'AynRandPaulRyan'},
#  'Thearst': {'AynRandPaulRyan'},
#  'rcrockett': {'AynRandPaulRyan'},
#  'jackiecall3': {'AynRandPaulRyan', 'kcleland', 'patrioticmomusa'},
#  'htownfeminista': {'AynRandPaulRyan'},
#  'Merrirrro': {'AynRandPaulRyan'},
#  '_dralaterdzo': {'AynRandPaulRyan', 'CaptainsLog2017', 'ProudResister'},
#  'MattMurph24': {'AynRandPaulRyan',
#   'GarrettRuby',
#   'ResistTilDeath',
#   'monaeltahawy'},
#  'RolndKarl': {'AynRandPaulRyan'},
#  'lkjtexas': {'AynRandPaulRyan', 'kharyp'},
#  'BernadetteMhill': {'AynRandPaulRyan', 'StormResist'},
#  'dittycommittee': {'AynRandPaulRyan'},
#  'mercury_road': {'AynRandPaulRyan'},
#  'realchrisdantes': {'PjjPjoje', '_ShaunDougherty', 'erezshek'},
#  'EmilyRB': {'Genosworld'},
#  'talk_mj': {'AndyQashou', 'BKnight1995', 'ProudResister', 'omarvaid'},
#  'oceanshaman': {'Shoq'},
#  'waltb31': {'CC4Future',
#   'DMansini',
#   'ManMet80',
#   'ProudResister',
#   'Shoq',
#   'docrocktex26'},
#  'tampagirl19655': {'Shoq'},
#  'austin_c_rick': {'kristenhinkson'},
#  'karenricks': {'kristenhinkson'},
#  'YamileJana': {'NotInMyMarines'},
#  'Whitdiane47': {'NotInMyMarines'},
#  'KgKathryn': {'PattyArquette'},
#  'judeaa': {'PattyArquette'},
#  'AmbraBattilana': {'ivanamassetti'},
#  'IndieJenFischer': {'WomenFilmOfColr'},
#  'Jeannie_Hartley': {'RethinkingEve'},
#  'ERAUSANOW': {'RethinkingEve', 'gabbyeubank', 'kcleland'},
#  'saralynne65': {'PrincessBravato', 'winterthur'},
#  'retsofdk': {'PrincessBravato'},
#  'sar_oso': {'PrincessBravato'},
#  'HillaryHutton': {'PrincessBravato'},
#  'scorpio292u': {'PrincessBravato'},
#  'GaladrielResist': {'Elastigirl2018', 'NurseChapel2017'},
#  'HarryPotterMAGE': {'Elastigirl2018', 'StormResist'},
#  'THESTRA50825107': {'ProudResister', 'SlythSeeker2017'},
#  'LesleyPro_04': {'SlythSeeker2017'},
#  'carinakolodny': {'kellysue'},
#  'monaeltahawy': {'DMAE2',
#   'EricaLWilliams7',
#   'GarrettRuby',
#   'JaneCaro',
#   'JustineLavaworm',
#   'LuvMultimedia',
#   'MattMurph24',
#   'NoFascistsPls',
#   'Tamara__Barnett',
#   'TinaTinde',
#   'VeritasEver',
#   'ejwillingham',
#   'jambie61',
#   'kellysue',
#   'lacunalingua',
#   'letat_lechat',
#   'najwazebian',
#   'rent_hero',
#   'seiliia'},
#  'Me_Too_Us': {'RYBWomen',
#   'TinaTinde',
#   'alaskawater',
#   'kellysue',
#   'protesting2016'},
#  'dorothyk98': {'MOVEprofPHD'},
#  'Andywoodward44': {'SaraJaneMaki'},
#  'KayZed14': {'ProudResister'},
#  'randyprine': {'ProudResister', 'meganmckenzie94'},
#  'badgirl_loony': {'ProudResister'},
#  'idlechatter91': {'ProudResister'},
#  'parkse': {'ManMet80', 'Maryc1850Sadler', 'ProudResister'},
#  '2013Tran': {'ProudResister'},
#  'a_fly_guy': {'ProudResister'},
#  'ohwhatsina': {'ProudResister'},
#  'StephenWunderl4': {'ProudResister'},
#  'HeyNikki1': {'ProudResister'},
#  'SullivanMonty': {'ProudResister'},
#  'deejay90192': {'BeverleeHughes3',
#   'GayEqualGlobal',
#   'KimbyIndy',
#   'ProudResister',
#   'SimpleWonders82',
#   'bannerite'},
#  'CaptainsLog2017': {'ProudResister',
#   'TaggartRehnn',
#   '_dralaterdzo',
#   'iSenseChange',
#   'lavenderblue27',
#   'lola_patty',
#   'whatllufallfor'},
#  'Only4RM': {'ProudResister', 'bruntofitall', 'jambie61', 'kkhooray'},
#  'paty1209f': {'ProudResister'},
#  'PMueller2': {'ProudResister'},
#  'Fisher_DanaR': {'ProudResister'},
#  'Bella_ofA': {'PolitiKiss1600', 'ProudResister'},
#  'costlylovewins': {'ProudResister', 'omarvaid'},
#  'laureldavilacpa': {'6nsinvt',
#   'BlackNewbornDem',
#   'CJPatruno',
#   'ProudResister',
#   'debbiesideris'},
#  'CJPatruno': {'B52Malmet',
#   'MarionBurr5',
#   'ProudResister',
#   'TaggartRehnn',
#   'debbiesideris',
#   'laureldavilacpa'},
#  'bmangh': {'ProudResister'},
#  'Can_ada': {'omarvaid'},
#  'MsTeacher80': {'omarvaid'},
#  'kansasfemale': {'SAdemocrat', 'SunflowerSoul71', 'carlettej1', 'omarvaid'},
#  'Snarking_tRump': {'omarvaid'},
#  'mamaduck9370': {'omarvaid'},
#  'KiwiShame': {'omarvaid'},
#  'KellieResists': {'MooseLambResist',
#   'SteveIParty',
#   'horridpoplyrics',
#   'negasonic2017',
#   'omarvaid'},
#  'CherokeeNative3': {'omarvaid'},
#  'JacquelineHine1': {'omarvaid'},
#  'ManMet80': {'omarvaid', 'parkse', 'waltb31'},
#  'joncoopertweets': {'AllonsyCrazy',
#   'CltrotLyn',
#   'Justica4all',
#   'Kschmidt67',
#   'LisaHauser8',
#   'MDemforce',
#   'PhoenixTatsCuts',
#   'TXMarLo',
#   'Thedude67111',
#   'Tlyncan',
#   'TomWellborn',
#   'chippy3166',
#   'omarvaid',
#   'sharonvt75'},
#  'bjorkianrice': {'Astartiel',
#   'KATHLEE23339303',
#   'OHenryHernandez',
#   'PrivateAbyss',
#   'SoulFlyTry',
#   'lisamikol1969',
#   'omarvaid'},
#  'GSB5719': {'omarvaid'},
#  'Michellamio': {'omarvaid'},
#  'HD4sanity_USAF': {'omarvaid'},
#  'LisaHauser8': {'joncoopertweets', 'omarvaid'},
#  'lacadri34': {'omarvaid'},
#  'TheOnlyAlyMack': {'omarvaid'},
#  'personalitty': {'omarvaid'},
#  'Boba_Cup': {'negasonic2017', 'omarvaid'},
#  'merryws95': {'omarvaid'},
#  'KarenEd04044347': {'omarvaid'},
#  'ccngg25': {'debbiesideris'},
#  'Astartiel': {'bjorkianrice', 'debbiesideris'},
#  'WeNeededHillary': {'debbiesideris'},
#  'lsfarmer311': {'debbiesideris'},
#  'halesr2539': {'ScaryHomeschool', 'debbiesideris'},
#  'B52Malmet': {'CJPatruno',
#   'FrecklesXX20',
#   'LadySif2017',
#   'Maryc1850Sadler',
#   'debbiesideris',
#   'whatthefox'},
#  'Wellness4You13': {'ArianeBellamar', 'StormResist', 'docrocktex26'},
#  'scarletsletter': {'ArianeBellamar'},
#  'ToddHagopian': {'ArianeBellamar'},
#  'TomWellborn': {'ArianeBellamar', 'joncoopertweets'},
#  'DrNat01': {'Robyn_Resists'},
#  'DMansini': {'dawnresist', 'waltb31'},
#  'Christi49131837': {'ProgressiveTex', 'debiowens'},
#  'seterapia': {'DMAE2', 'GGevirtz', 'ProgressiveTex'},
#  'GarrettRuby': {'MattMurph24', 'arijameiers', 'monaeltahawy'},
#  'harmonyis1': {'arijameiers'},
#  'summer7570': {'LalaMusings', 'arijameiers', 'patrioticmomusa'},
#  'PuestoLoco': {'AudreyGarden',
#   'BeverleeHughes3',
#   'CaraOriel',
#   'PjjPjoje',
#   'ShannonEG68',
#   'arijameiers',
#   'bannerite',
#   'djmincey11',
#   'jawja100'},
#  'erezshek': {'realchrisdantes'},
#  'AndyQashou': {'talk_mj'},
#  'CC4Future': {'Anootchka', 'waltb31'},
#  'docrocktex26': {'DMAE2',
#   'LisaTalmadge',
#   'RFreeba',
#   'Wellness4You13',
#   'waltb31'},
#  'YoureWonder': {'LMovieLowdown', 'RYBWomen'},
#  'gemma_brett': {'MeTooShortFilm',
#   'Passie_Kracht',
#   'Shy_Survivor',
#   'bjportraits',
#   'feraldaughter',
#   'unbreakablepenn'},
#  'kcleland': {'Bfolly', 'ERAUSANOW', 'jackiecall3'},
#  'winterthur': {'saralynne65'},
#  'StormResist': {'BKmelo70',
#   'BernadetteMhill',
#   'CharleyUtah',
#   'CondieKristine',
#   'HarryPotterMAGE',
#   'Wellness4You13',
#   'kkhooray'},
#  'NurseChapel2017': {'GaladrielResist'},
#  'lacunalingua': {'monaeltahawy'},
#  'rent_hero': {'monaeltahawy'},
#  'LuvMultimedia': {'monaeltahawy'},
#  'JaneCaro': {'ABCthedrum', 'monaeltahawy', 'whereisdaz'},
#  'DMAE2': {'docrocktex26', 'monaeltahawy', 'seterapia'},
#  'VeritasEver': {'monaeltahawy'},
#  'JustineLavaworm': {'monaeltahawy'},
#  'jambie61': {'Only4RM', 'PjjPjoje', 'letat_lechat', 'monaeltahawy'},
#  'ejwillingham': {'monaeltahawy'},
#  'Tamara__Barnett': {'monaeltahawy'},
#  'EricaLWilliams7': {'monaeltahawy'},
#  'seiliia': {'monaeltahawy'},
#  'najwazebian': {'WesthaverEmily', 'monaeltahawy'},
#  'protesting2016': {'Me_Too_Us'},
#  'RYBWomen': {'Me_Too_Us', 'TinaTinde', 'YoureWonder'},
#  'alaskawater': {'Me_Too_Us'},
#  'TaggartRehnn': {'CJPatruno', 'CaptainsLog2017', 'Damian_7', 'bannerite'},
#  'lola_patty': {'CaptainsLog2017'},
#  'whatllufallfor': {'1feralkat', 'CaptainsLog2017'},
#  'iSenseChange': {'CaptainsLog2017', 'blizzyou'},
#  'lavenderblue27': {'CaptainsLog2017'},
#  '6nsinvt': {'laureldavilacpa'},
#  'BlackNewbornDem': {'laureldavilacpa'},
#  'bannerite': {'PuestoLoco', 'TaggartRehnn', 'deejay90192'},
#  'GayEqualGlobal': {'deejay90192'},
#  'BeverleeHughes3': {'PuestoLoco', 'deejay90192', 'letat_lechat'},
#  'SimpleWonders82': {'deejay90192'},
#  'PolitiKiss1600': {'Bella_ofA', 'MonicaNocciola'},
#  'MarionBurr5': {'CJPatruno'},
#  'bruntofitall': {'Only4RM', 'kentuckygrandma'},
#  'kkhooray': {'Only4RM', 'StormResist'},
#  'MooseLambResist': {'KellieResists', 'windmillcharger'},
#  'meganmckenzie94': {'randyprine'},
#  'sharonvt75': {'joncoopertweets'},
#  'chippy3166': {'joncoopertweets'},
#  'Thedude67111': {'joncoopertweets'},
#  'TXMarLo': {'joncoopertweets'},
#  'Tlyncan': {'Carmen_TD8_', 'joncoopertweets'},
#  'MDemforce': {'joncoopertweets'},
#  'Kschmidt67': {'joncoopertweets'},
#  'CltrotLyn': {'joncoopertweets'},
#  'PhoenixTatsCuts': {'joncoopertweets'},
#  'AllonsyCrazy': {'joncoopertweets'},
#  'Justica4all': {'NiceChess757', 'joncoopertweets'},
#  'OHenryHernandez': {'PrivateAbyss', 'Randycomesup', 'bjorkianrice'},
#  'PrivateAbyss': {'AlasscanIsBack',
#   'OHenryHernandez',
#   'SmallFarmDairy',
#   'bjorkianrice'},
#  'SoulFlyTry': {'bjorkianrice'},
#  'lisamikol1969': {'SunflowerSoul71', 'bjorkianrice', 'donna_spackman'},
#  'KATHLEE23339303': {'Tellall2012', 'bjorkianrice'},
#  'SunflowerSoul71': {'LouiseBagshawe',
#   'WonderWoman934',
#   'YvetteKopp',
#   'comehithercreek',
#   'kansasfemale',
#   'lisamikol1969',
#   'stephan08347556'},
#  'SAdemocrat': {'Julia_in_DE', 'kansasfemale'},
#  'carlettej1': {'Carmen_TD8_', 'debiowens', 'kansasfemale'},
#  'negasonic2017': {'Boba_Cup',
#   'GrootResists',
#   'KellieResists',
#   'WisePaxCat',
#   'brat2381'},
#  'horridpoplyrics': {'AmyOddo', 'KellieResists', 'VoteforUSA2017'},
#  'SteveIParty': {'KellieResists'},
#  'whatthefox': {'B52Malmet', 'jenscorpio83'},
#  'Maryc1850Sadler': {'B52Malmet', 'parkse'},
#  'FrecklesXX20': {'B52Malmet'},
#  'LadySif2017': {'B52Malmet'},
#  'ScaryHomeschool': {'halesr2539'},
#  'debiowens': {'Christi49131837', 'carlettej1'},
#  'GGevirtz': {'seterapia'},
#  'djmincey11': {'PuestoLoco', 'theAWParty'},
#  'AudreyGarden': {'PuestoLoco'},
#  'CaraOriel': {'PuestoLoco'},
#  'jawja100': {'PolitiScoop', 'PuestoLoco', 'wff1022'},
#  'LalaMusings': {'summer7570'},
#  'patrioticmomusa': {'jackiecall3', 'summer7570'},
#  'WgarNews': {'PjjPjoje', 'lynlinking', 'newmatilda'},
#  'kitty4hawks': {'PjjPjoje', 'mrsmichaud13'},
#  'RFreeba': {'AlasscanIsBack', 'docrocktex26'},
#  'Anootchka': {'CC4Future'},
#  'MeTooShortFilm': {'gemma_brett'},
#  'feraldaughter': {'gemma_brett'},
#  'bjportraits': {'gemma_brett'},
#  'Shy_Survivor': {'RoxanneSukhan', 'gemma_brett'},
#  'Passie_Kracht': {'gemma_brett'},
#  'Bfolly': {'ERAMinnesota', 'kcleland'},
#  'BKmelo70': {'StormResist'},
#  'CharleyUtah': {'StormResist'},
#  'CondieKristine': {'StormResist'},
#  'WesthaverEmily': {'najwazebian'},
#  'HeleenTouquet': {'TinaTinde'},
#  'cfiig8200': {'Kvindesamfund', 'TinaTinde'},
#  'KlassmannAngela': {'TinaTinde'},
#  'vitalifranc': {'TinaTinde'},
#  'cinemaven': {'letat_lechat'},
#  'DrLindaShelton': {'letat_lechat', 'melodijoy'},
#  'TheCampaignFilm': {'letat_lechat'},
#  'MooPersists': {'birdgirl1001', 'letat_lechat'},
#  'theAWParty': {'ICarrollJ',
#   'QueenMab87',
#   'SallyAlbright',
#   'djmincey11',
#   'letat_lechat'},
#  'birdgirl1001': {'MooPersists', 'letat_lechat'},
#  'Plantflowes': {'armsivilli', 'letat_lechat'},
#  'edgeoforever': {'letat_lechat'},
#  'ResistTilDeath': {'MattMurph24'},
#  'ABCthedrum': {'AllThingsAfrica',
#   'JaneCaro',
#   'NotUnderBondage',
#   'SallyRMelb',
#   'SpotlightForYou',
#   'raywilton4',
#   'whereisdaz'},
#  'whereisdaz': {'ABCthedrum', 'JaneCaro'},
#  'pahstock': {'NoFascistsPls'},
#  'JConabicycle': {'KittyAndPitty', 'NoFascistsPls', 'SmallFarmDairy'},
#  'Damian_7': {'TaggartRehnn'},
#  'blizzyou': {'iSenseChange'},
#  '1feralkat': {'whatllufallfor'},
#  'MonicaNocciola': {'PolitiKiss1600'},
#  'kentuckygrandma': {'bruntofitall'},
#  'NiceChess757': {'Justica4all'},
#  'Randycomesup': {'OHenryHernandez'},
#  'SmallFarmDairy': {'JConabicycle', 'PrivateAbyss'},
#  'AlasscanIsBack': {'PrivateAbyss', 'RFreeba'},
#  'donna_spackman': {'lisamikol1969'},
#  'Tellall2012': {'KATHLEE23339303'},
#  'stephan08347556': {'SunflowerSoul71'},
#  'LouiseBagshawe': {'SunflowerSoul71'},
#  'YvetteKopp': {'SunflowerSoul71'},
#  'comehithercreek': {'SunflowerSoul71'},
#  'WonderWoman934': {'SunflowerSoul71'},
#  'Julia_in_DE': {'SAdemocrat'},
#  'AmyOddo': {'horridpoplyrics'},
#  'VoteforUSA2017': {'horridpoplyrics'},
#  'brat2381': {'negasonic2017'},
#  'WisePaxCat': {'negasonic2017'},
#  'GrootResists': {'negasonic2017'},
#  'wff1022': {'jawja100'},
#  'PolitiScoop': {'jawja100'},
#  'xscoutie': {'ShannonEG68'},
#  'lynlinking': {'WgarNews'},
#  'newmatilda': {'WgarNews'},
#  'mrsmichaud13': {'kitty4hawks'},
#  'sdterp': {'LisaTalmadge'},
#  'RoxanneSukhan': {'Shy_Survivor'},
#  'ERAMinnesota': {'Bfolly'},
#  'Kvindesamfund': {'cfiig8200'},
#  'missydiggs': {'QueenMab87'},
#  'ICarrollJ': {'theAWParty'},
#  'SallyAlbright': {'theAWParty'},
#  'melodijoy': {'DrLindaShelton'},
#  'armsivilli': {'Plantflowes'},
#  'SallyRMelb': {'ABCthedrum'},
#  'AllThingsAfrica': {'ABCthedrum'},
#  'SpotlightForYou': {'ABCthedrum'},
#  'raywilton4': {'ABCthedrum'},
#  'NotUnderBondage': {'ABCthedrum'},
#  'KittyAndPitty': {'JConabicycle'},
#  'TaranaBurke': {'AngryBlackLady',
#   'BettyBuckley',
#   'Blackamazon',
#   'BreaktheCycleDV',
#   'CeciliaNano',
#   'Compassioning',
#   'EmmaBunnie',
#   'EqualRightsAdv',
#   'GGENYC',
#   'IBJIYONGI',
#   'IWriteAllDay_',
#   'JW4Resistance',
#   'JeanHyams',
#   'PattyArquette',
#   'QueenMab87',
#   'ShaunKing',
#   'YWCA_Canada',
#   'aijenpoo',
#   'domesticworkers',
#   'farrah_khan',
#   'kharyp',
#   'knowyourIX',
#   'leanne4pa',
#   'nwseal11',
#   'shanikharris',
#   'shreec',
#   'sreneelong',
#   'windmillcharger'},
#  'Alyssa_Milano': {'Amoney666',
#   'ArianeBellamar',
#   'Carmen_TD8_',
#   'EmmaBunnie',
#   'Genosworld',
#   'JSavoly',
#   'Mattison',
#   'MaureenShaw',
#   'PaganMediaBites',
#   'PjjPjoje',
#   'RachelAzzara',
#   'VA174navyvet',
#   'VintageKnits',
#   'YourAnonRevolt',
#   'amplifirenews_',
#   'cindygallop',
#   'evry2min',
#   'letat_lechat',
#   'mattnicholas',
#   'paulpender1',
#   'rubybelson',
#   'safeagain1',
#   'serenityatsea',
#   'wendydshaffer'},
#  'LaurenJauregui': {'DREWSINGS',
#   'DulleyTopBooks',
#   'JessesGirl588',
#   'JustChar83',
#   'KelciRee',
#   'MichelleSauber',
#   'PaganMediaBites',
#   'halevader',
#   'infLAURENZA',
#   'kristenhinkson',
#   'nicolexhames'},
#  'SenGillibrand': {'AuthorKimberley',
#   'BKnight1995',
#   'BrianSwiftie13',
#   'IndivisNewRoc',
#   'JenSiebelNewsom',
#   'LisaTalmadge',
#   'MadisonSiriusXM',
#   'NoFascistsPls',
#   'Ophelia22345',
#   'PaganMediaBites',
#   'PjjPjoje',
#   'ReignOfApril',
#   'RobinBrenizer',
#   'ShannonEG68',
#   'SophiaBush',
#   'TexDem16',
#   'TinaTinde',
#   'VintageKnits',
#   'WomenOccupyHwd',
#   'YMBBastepaway',
#   'YWCA_Canada',
#   'ashleyn1cole',
#   'chillibeanboy',
#   'donohue_rebekah',
#   'ivanamassetti',
#   'shanikharris',
#   'terriah01',
#   'unbreakablepenn',
#   'wendydshaffer'}}

# %%
net.neighbors('TaranaBurke')
# Out:
# {'AngryBlackLady',
#  'BettyBuckley',
#  'Blackamazon',
#  'BreaktheCycleDV',
#  'EqualRightsAdv',
#  'IBJIYONGI',
#  'JW4Resistance',
#  'PattyArquette',
#  'QueenMab87',
#  'ShaunKing',
#  'YWCA_Canada',
#  'aijenpoo',
#  'domesticworkers',
#  'farrah_khan',
#  'kharyp',
#  'knowyourIX',
#  'leanne4pa',
#  'shanikharris',
#  'windmillcharger'}
